# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | ikom
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | aqtobe
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | chuy
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | south venice
# Processing Record 14 of Set 1 | maraa
# Processing Record 15 of Set 1 | saint-joseph
# Processing Record 16 of Set 1 | kargasok
# Processing Record 17 of Set 1 | prince rupert
# Processing Record 18 of Set 1 | codrington
# Processing Record 19 of Set 1 | sinnamary
# Processing Record 20 of Set 1 | vokhtoga
# Processing Record 21 of Set 1 | kieta
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | krasnoarmeysk
# Processing Record 25 of Set 1 | harper
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | bam
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | port lincoln
# Processing Record 31 of Set 1 | samarai
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | martapura
# Processing Record 35 of Set 1 | west wendover
# Processing Record 36 of Set 1 | mount gambier
# Processing Record 37 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 1 | camden
# Processing Record 41 of Set 1 | katsuura
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 1 | palmer
# Processing Record 45 of Set 1 | beloha
# Processing Record 46 of Set 1 | tecoanapa
# Processing Record 47 of Set 1 | puhja
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | cabedelo
# Processing Record 0 of Set 2 | qaqortoq
# Processing Record 1 of Set 2 | bathsheba
# Processing Record 2 of Set 2 | saint-francois
# Processing Record 3 of Set 2 | deputatskiy
# Processing Record 4 of Set 2 | kalmunai
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | kilindoni
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | mirabad
# Processing Record 10 of Set 2 | garowe
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | bud
# Processing Record 13 of Set 2 | sampit
# Processing Record 14 of Set 2 | baykit
# Processing Record 15 of Set 2 | nushki
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | labuhan
# Processing Record 19 of Set 2 | omsukchan
# Processing Record 20 of Set 2 | sunrise manor
# Processing Record 21 of Set 2 | sioux lookout
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | bambous virieux
# Processing Record 26 of Set 2 | flinders
# Processing Record 27 of Set 2 | lata
# Processing Record 28 of Set 2 | shubarkuduk
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | ocos
# Processing Record 32 of Set 2 | sao filipe
# Processing Record 33 of Set 2 | araguaina
# Processing Record 34 of Set 2 | taltal
# Processing Record 35 of Set 2 | gornoye loo
# Processing Record 36 of Set 2 | yerbogachen
# Processing Record 37 of Set 2 | cordeiro
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | constitucion
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | geilo
# Processing Record 42 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | sao joao da barra
# Processing Record 45 of Set 2 | fort-shevchenko
# Processing Record 46 of Set 2 | jaciara
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | san andres
# Processing Record 49 of Set 2 | sao felix do xingu
# Processing Record 0 of Set 3 | new norfolk
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | ninotsminda
# Processing Record 4 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 5 of Set 3 | tiznit
# Processing Record 6 of Set 3 | karratha
# Processing Record 7 of Set 3 | rosa zarate
# Processing Record 8 of Set 3 | dicabisagan
# Processing Record 9 of Set 3 | ankazobe
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | jacareacanga
# Processing Record 12 of Set 3 | pangnirtung
# Processing Record 13 of Set 3 | kulhudhuffushi
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | mayor pablo lagerenza
# Processing Record 18 of Set 3 | vestmanna
# Processing Record 19 of Set 3 | tura
# Processing Record 20 of Set 3 | kraskino
# Processing Record 21 of Set 3 | busselton
# Processing Record 22 of Set 3 | esperance
# Processing Record 23 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 3 | henties bay
# Processing Record 25 of Set 3 | myitkyina
# Processing Record 26 of Set 3 | koyelga
# Processing Record 27 of Set 3 | olafsvik
# Processing Record 28 of Set 3 | tuatapere
# Processing Record 29 of Set 3 | saveh
# Processing Record 30 of Set 3 | sorong
# Processing Record 31 of Set 3 | wilmington island
# Processing Record 32 of Set 3 | faya
# Processing Record 33 of Set 3 | georgetown
# Processing Record 34 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | ilulissat
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | wanning
# Processing Record 39 of Set 3 | mahebourg
# Processing Record 40 of Set 3 | havelock
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | lompoc
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | rio grande
# Processing Record 45 of Set 3 | henzada
# City not found. Skipping...
# Processing Record 46 of Set 3 | cayenne
# Processing Record 47 of Set 3 | riyadh
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | bom jesus
# Processing Record 0 of Set 4 | tahta
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | axim
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | hithadhoo
# Processing Record 5 of Set 4 | mangai
# Processing Record 6 of Set 4 | sidi qasim
# City not found. Skipping...
# Processing Record 7 of Set 4 | rassvet
# Processing Record 8 of Set 4 | paamiut
# Processing Record 9 of Set 4 | cape town
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | sambava
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | caravelas
# Processing Record 15 of Set 4 | arcoverde
# Processing Record 16 of Set 4 | tilichiki
# Processing Record 17 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 4 | nelson bay
# Processing Record 19 of Set 4 | balikpapan
# Processing Record 20 of Set 4 | puerto ayora
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | lorengau
# Processing Record 23 of Set 4 | taga dzong
# City not found. Skipping...
# Processing Record 24 of Set 4 | dingle
# Processing Record 25 of Set 4 | severnoye
# Processing Record 26 of Set 4 | puro
# Processing Record 27 of Set 4 | peace river
# Processing Record 28 of Set 4 | havoysund
# Processing Record 29 of Set 4 | sokolo
# Processing Record 30 of Set 4 | pangoa
# Processing Record 31 of Set 4 | luderitz
# Processing Record 32 of Set 4 | kangaatsiaq
# Processing Record 33 of Set 4 | vestmannaeyjar
# Processing Record 34 of Set 4 | bonthe
# Processing Record 35 of Set 4 | kavieng
# Processing Record 36 of Set 4 | korla
# Processing Record 37 of Set 4 | barrhead
# Processing Record 38 of Set 4 | bolshaya murta
# City not found. Skipping...
# Processing Record 39 of Set 4 | hofn
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | kahului
# Processing Record 42 of Set 4 | araceli
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | powell
# Processing Record 45 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 4 | padang
# Processing Record 47 of Set 4 | saldanha
# Processing Record 48 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 49 of Set 4 | poso
# Processing Record 0 of Set 5 | danville
# Processing Record 1 of Set 5 | khash
# Processing Record 2 of Set 5 | isla vista
# Processing Record 3 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 5 | biak
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | inhambane
# Processing Record 7 of Set 5 | slave lake
# Processing Record 8 of Set 5 | coahuayana
# Processing Record 9 of Set 5 | leshukonskoye
# Processing Record 10 of Set 5 | makakilo city
# Processing Record 11 of Set 5 | puerto escondido
# Processing Record 12 of Set 5 | grindavik
# Processing Record 13 of Set 5 | rundu
# Processing Record 14 of Set 5 | paso de ovejas
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | lavumisa
# Processing Record 18 of Set 5 | hervey bay
# Processing Record 19 of Set 5 | nouadhibou
# Processing Record 20 of Set 5 | mazara del vallo
# Processing Record 21 of Set 5 | quetame
# Processing Record 22 of Set 5 | atlantic city
# Processing Record 23 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 5 | sibolga
# Processing Record 25 of Set 5 | turayf
# Processing Record 26 of Set 5 | san cristobal
# Processing Record 27 of Set 5 | lovozero
# Processing Record 28 of Set 5 | iqaluit
# Processing Record 29 of Set 5 | severiano melo
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | ust-uda
# Processing Record 32 of Set 5 | yamada
# Processing Record 33 of Set 5 | honningsvag
# Processing Record 34 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 5 | cacheu
# Processing Record 36 of Set 5 | kaseda
# Processing Record 37 of Set 5 | karpenision
# City not found. Skipping...
# Processing Record 38 of Set 5 | pytalovo
# Processing Record 39 of Set 5 | ilembo
# Processing Record 40 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 5 | porto novo
# Processing Record 42 of Set 5 | altay
# Processing Record 43 of Set 5 | muravlenko
# Processing Record 44 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 5 | half moon bay
# Processing Record 46 of Set 5 | ahipara
# Processing Record 47 of Set 5 | mitu
# Processing Record 48 of Set 5 | noumea
# Processing Record 49 of Set 5 | kutum
# Processing Record 0 of Set 6 | abilene
# Processing Record 1 of Set 6 | ossora
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | gamba
# Processing Record 4 of Set 6 | rosario
# Processing Record 5 of Set 6 | bethel
# Processing Record 6 of Set 6 | saint anthony
# Processing Record 7 of Set 6 | san patricio
# Processing Record 8 of Set 6 | yellowknife
# Processing Record 9 of Set 6 | aruppukkottai
# Processing Record 10 of Set 6 | fortuna
# Processing Record 11 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 6 | vila nova de milfontes
# Processing Record 13 of Set 6 | luena
# Processing Record 14 of Set 6 | huarmey
# Processing Record 15 of Set 6 | ostrovnoy
# Processing Record 16 of Set 6 | blackwater
# Processing Record 17 of Set 6 | lebu
# Processing Record 18 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 6 | lagoa
# Processing Record 20 of Set 6 | morden
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | tay ninh
# Processing Record 23 of Set 6 | darnah
# Processing Record 24 of Set 6 | pochutla
# Processing Record 25 of Set 6 | williams lake
# Processing Record 26 of Set 6 | wanaka
# Processing Record 27 of Set 6 | ponta do sol
# Processing Record 28 of Set 6 | winnemucca
# Processing Record 29 of Set 6 | kaputa
# Processing Record 30 of Set 6 | doha
# Processing Record 31 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 6 | pisco
# Processing Record 33 of Set 6 | san isidro
# Processing Record 34 of Set 6 | hualmay
# Processing Record 35 of Set 6 | trinidad
# Processing Record 36 of Set 6 | bengkulu
# Processing Record 37 of Set 6 | bodden town
# Processing Record 38 of Set 6 | kruisfontein
# Processing Record 39 of Set 6 | abha
# Processing Record 40 of Set 6 | acajutla
# Processing Record 41 of Set 6 | vanimo
# Processing Record 42 of Set 6 | sudak
# Processing Record 43 of Set 6 | zhangye
# Processing Record 44 of Set 6 | suntar
# Processing Record 45 of Set 6 | stykkisholmur
# Processing Record 46 of Set 6 | buncrana
# Processing Record 47 of Set 6 | montepuez
# Processing Record 48 of Set 6 | vokhma
# Processing Record 49 of Set 6 | pemba
# Processing Record 0 of Set 7 | los llanos de aridane
# Processing Record 1 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 7 | rognan
# Processing Record 3 of Set 7 | takoradi
# Processing Record 4 of Set 7 | rawson
# Processing Record 5 of Set 7 | choya
# Processing Record 6 of Set 7 | mankera
# Processing Record 7 of Set 7 | port arthur
# Processing Record 8 of Set 7 | ribas do rio pardo
# Processing Record 9 of Set 7 | ternate
# Processing Record 10 of Set 7 | gaya
# Processing Record 11 of Set 7 | acarau
# Processing Record 12 of Set 7 | yokadouma
# Processing Record 13 of Set 7 | tawzar
# City not found. Skipping...
# Processing Record 14 of Set 7 | magrath
# Processing Record 15 of Set 7 | klaksvik
# Processing Record 16 of Set 7 | shimoda
# Processing Record 17 of Set 7 | kemijarvi
# Processing Record 18 of Set 7 | khatanga
# Processing Record 19 of Set 7 | vila franca do campo
# Processing Record 20 of Set 7 | sergeyevka
# Processing Record 21 of Set 7 | santa maria
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | maragheh
# Processing Record 24 of Set 7 | viedma
# Processing Record 25 of Set 7 | marawi
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | yulara
# Processing Record 28 of Set 7 | cockburn town
# Processing Record 29 of Set 7 | salalah
# Processing Record 30 of Set 7 | ulladulla
# Processing Record 31 of Set 7 | vasteras
# Processing Record 32 of Set 7 | cabo san lucas
# Processing Record 33 of Set 7 | manjacaze
# Processing Record 34 of Set 7 | necochea
# Processing Record 35 of Set 7 | hasaki
# Processing Record 36 of Set 7 | encheng
# Processing Record 37 of Set 7 | port hedland
# Processing Record 38 of Set 7 | westport
# Processing Record 39 of Set 7 | kamina
# Processing Record 40 of Set 7 | booue
# Processing Record 41 of Set 7 | dubbo
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | ereymentau
# Processing Record 44 of Set 7 | kloulklubed
# Processing Record 45 of Set 7 | washington
# Processing Record 46 of Set 7 | nurota
# Processing Record 47 of Set 7 | ponta delgada
# Processing Record 48 of Set 7 | maralal
# Processing Record 49 of Set 7 | san policarpo
# Processing Record 0 of Set 8 | tulum
# Processing Record 1 of Set 8 | roald
# Processing Record 2 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 3 of Set 8 | guerrero negro
# Processing Record 4 of Set 8 | hamilton
# Processing Record 5 of Set 8 | phan thiet
# Processing Record 6 of Set 8 | atocha
# Processing Record 7 of Set 8 | hurghada
# Processing Record 8 of Set 8 | binucayan
# Processing Record 9 of Set 8 | okha
# Processing Record 10 of Set 8 | sal rei
# Processing Record 11 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | borovskoy
# Processing Record 14 of Set 8 | berlevag
# Processing Record 15 of Set 8 | norrtalje
# Processing Record 16 of Set 8 | davila
# Processing Record 17 of Set 8 | saint-augustin
# Processing Record 18 of Set 8 | loukhi
# Processing Record 19 of Set 8 | serov
# Processing Record 20 of Set 8 | vao
# Processing Record 21 of Set 8 | general roca
# Processing Record 22 of Set 8 | broome
# Processing Record 23 of Set 8 | san quintin
# Processing Record 24 of Set 8 | ust-maya
# Processing Record 25 of Set 8 | hanna
# Processing Record 26 of Set 8 | duvan
# Processing Record 27 of Set 8 | ilovlya
# Processing Record 28 of Set 8 | apatou
# Processing Record 29 of Set 8 | palaia fokaia
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | hobyo
# Processing Record 32 of Set 8 | bac lieu
# Processing Record 33 of Set 8 | bulgan
# Processing Record 34 of Set 8 | aswan
# Processing Record 35 of Set 8 | ahuimanu
# Processing Record 36 of Set 8 | ust-kut
# Processing Record 37 of Set 8 | montmagny
# Processing Record 38 of Set 8 | addi ugri
# City not found. Skipping...
# Processing Record 39 of Set 8 | te anau
# Processing Record 40 of Set 8 | mitsamiouli
# Processing Record 41 of Set 8 | smolenka
# Processing Record 42 of Set 8 | lingao
# Processing Record 43 of Set 8 | nortelandia
# Processing Record 44 of Set 8 | ust-nera
# Processing Record 45 of Set 8 | mamlyutka
# Processing Record 46 of Set 8 | kharp
# Processing Record 47 of Set 8 | magliz
# City not found. Skipping...
# Processing Record 48 of Set 8 | vakhrushev
# Processing Record 49 of Set 8 | hovd
# Processing Record 0 of Set 9 | buraydah
# Processing Record 1 of Set 9 | edmundston
# Processing Record 2 of Set 9 | shadrinsk
# Processing Record 3 of Set 9 | neustrelitz
# Processing Record 4 of Set 9 | aksarka
# Processing Record 5 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 6 of Set 9 | saint george
# Processing Record 7 of Set 9 | kodinsk
# Processing Record 8 of Set 9 | bongandanga
# Processing Record 9 of Set 9 | port hardy
# Processing Record 10 of Set 9 | saint-georges
# Processing Record 11 of Set 9 | lahaina
# Processing Record 12 of Set 9 | flin flon
# Processing Record 13 of Set 9 | kouroussa
# Processing Record 14 of Set 9 | wangqing
# Processing Record 15 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 9 | khorramshahr
# Processing Record 17 of Set 9 | zaporizhzhya
# Processing Record 18 of Set 9 | oparino
# Processing Record 19 of Set 9 | airai
# Processing Record 20 of Set 9 | nuzvid
# Processing Record 21 of Set 9 | kamiiso
# Processing Record 22 of Set 9 | vila velha
# Processing Record 23 of Set 9 | coihaique
# Processing Record 24 of Set 9 | tautira
# Processing Record 25 of Set 9 | stephenville
# Processing Record 26 of Set 9 | talnakh
# Processing Record 27 of Set 9 | chimbote
# Processing Record 28 of Set 9 | kaitangata
# Processing Record 29 of Set 9 | bo rai
# Processing Record 30 of Set 9 | mnogovershinnyy
# Processing Record 31 of Set 9 | fukue
# Processing Record 32 of Set 9 | anadyr
# Processing Record 33 of Set 9 | chino valley
# Processing Record 34 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 9 | elizabeth city
# Processing Record 36 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 37 of Set 9 | mouila
# Processing Record 38 of Set 9 | thinadhoo
# Processing Record 39 of Set 9 | bolzano
# Processing Record 40 of Set 9 | invermere
# Processing Record 41 of Set 9 | balabac
# Processing Record 42 of Set 9 | moiyabana
# City not found. Skipping...
# Processing Record 43 of Set 9 | rockhampton
# Processing Record 44 of Set 9 | robertsport
# Processing Record 45 of Set 9 | ngunguru
# Processing Record 46 of Set 9 | kurmanayevka
# Processing Record 47 of Set 9 | mason city
# Processing Record 48 of Set 9 | belaya gora
# Processing Record 49 of Set 9 | alofi
# Processing Record 0 of Set 10 | la union
# Processing Record 1 of Set 10 | kijang
# Processing Record 2 of Set 10 | paptalaya
# Processing Record 3 of Set 10 | iskateley
# Processing Record 4 of Set 10 | mahanoro
# Processing Record 5 of Set 10 | zhoucheng
# Processing Record 6 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 10 | princeton
# Processing Record 8 of Set 10 | pedernales
# Processing Record 9 of Set 10 | sukumo
# Processing Record 10 of Set 10 | itami
# Processing Record 11 of Set 10 | erenhot
# Processing Record 12 of Set 10 | berdyuzhye
# City not found. Skipping...
# Processing Record 13 of Set 10 | leua
# Processing Record 14 of Set 10 | hodasz
# Processing Record 15 of Set 10 | jinji
# Processing Record 16 of Set 10 | atar
# Processing Record 17 of Set 10 | weymouth
# Processing Record 18 of Set 10 | foz
# Processing Record 19 of Set 10 | tiksi
# Processing Record 20 of Set 10 | farsund
# Processing Record 21 of Set 10 | antigonish
# Processing Record 22 of Set 10 | siverek
# Processing Record 23 of Set 10 | mayumba
# Processing Record 24 of Set 10 | mawlaik
# Processing Record 25 of Set 10 | andilamena
# Processing Record 26 of Set 10 | rovaniemi
# Processing Record 27 of Set 10 | poum
# Processing Record 28 of Set 10 | binga
# Processing Record 29 of Set 10 | north platte
# Processing Record 30 of Set 10 | vanavara
# Processing Record 31 of Set 10 | huilong
# Processing Record 32 of Set 10 | burns lake
# Processing Record 33 of Set 10 | corinto
# Processing Record 34 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 35 of Set 10 | konakovo
# Processing Record 36 of Set 10 | punta de bombon
# Processing Record 37 of Set 10 | talaya
# Processing Record 38 of Set 10 | sungaipenuh
# Processing Record 39 of Set 10 | indore
# Processing Record 40 of Set 10 | kathu
# Processing Record 41 of Set 10 | vrangel
# Processing Record 42 of Set 10 | methoni
# Processing Record 43 of Set 10 | pozo colorado
# Processing Record 44 of Set 10 | fez
# Processing Record 45 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 46 of Set 10 | polillo
# Processing Record 47 of Set 10 | vanaton
# City not found. Skipping...
# Processing Record 48 of Set 10 | praxedis guerrero
# Processing Record 49 of Set 10 | bubaque
# Processing Record 0 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 2 of Set 11 | piacabucu
# Processing Record 3 of Set 11 | langsa
# Processing Record 4 of Set 11 | marondera
# Processing Record 5 of Set 11 | funadhoo
# Processing Record 6 of Set 11 | college
# Processing Record 7 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 8 of Set 11 | welkom
# Processing Record 9 of Set 11 | tonj
# Processing Record 10 of Set 11 | mehamn
# Processing Record 11 of Set 11 | ust-ilimsk
# Processing Record 12 of Set 11 | jatai
# Processing Record 13 of Set 11 | roebourne
# Processing Record 14 of Set 11 | acapulco
# Processing Record 15 of Set 11 | port blair
# Processing Record 16 of Set 11 | hinton
# Processing Record 17 of Set 11 | pacific grove
# Processing Record 18 of Set 11 | muisne
# Processing Record 19 of Set 11 | bowen
# Processing Record 20 of Set 11 | ketchikan
# Processing Record 21 of Set 11 | sangar
# Processing Record 22 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 23 of Set 11 | caruray
# Processing Record 24 of Set 11 | mandalgovi
# Processing Record 25 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 26 of Set 11 | liniere
# City not found. Skipping...
# Processing Record 27 of Set 11 | sakakah
# Processing Record 28 of Set 11 | safakulevo
# Processing Record 29 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 11 | camacha
# Processing Record 31 of Set 11 | bridlington
# Processing Record 32 of Set 11 | pout
# Processing Record 33 of Set 11 | avera
# Processing Record 34 of Set 11 | kolondieba
# Processing Record 35 of Set 11 | sao borja
# Processing Record 36 of Set 11 | maragogi
# Processing Record 37 of Set 11 | los pozos
# Processing Record 38 of Set 11 | tooele
# Processing Record 39 of Set 11 | preston
# Processing Record 40 of Set 11 | jiangyan
# Processing Record 41 of Set 11 | araouane
# Processing Record 42 of Set 11 | coquimbo
# Processing Record 43 of Set 11 | miami
# Processing Record 44 of Set 11 | delijan
# Processing Record 45 of Set 11 | kashan
# Processing Record 46 of Set 11 | provideniya
# Processing Record 47 of Set 11 | sault sainte marie
# Processing Record 48 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 11 | ouadda
# Processing Record 0 of Set 12 | auki
# Processing Record 1 of Set 12 | taoudenni
# Processing Record 2 of Set 12 | bairiki
# Processing Record 3 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 12 | bandarbeyla
# Processing Record 5 of Set 12 | xining
# Processing Record 6 of Set 12 | calobre
# City not found. Skipping...
# Processing Record 7 of Set 12 | palauig
# Processing Record 8 of Set 12 | shache
# Processing Record 9 of Set 12 | rio gallegos
# Processing Record 10 of Set 12 | mayo
# Processing Record 11 of Set 12 | geraldton
# Processing Record 12 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 12 | tagab
# Processing Record 14 of Set 12 | ntungamo
# Processing Record 15 of Set 12 | mae ramat
# Processing Record 16 of Set 12 | urumqi
# Processing Record 17 of Set 12 | kalanchak
# Processing Record 18 of Set 12 | rustenburg
# Processing Record 19 of Set 12 | merrill
# Processing Record 20 of Set 12 | awbari
# Processing Record 21 of Set 12 | port macquarie
# Processing Record 22 of Set 12 | penzance
# Processing Record 23 of Set 12 | kysyl-syr
# Processing Record 24 of Set 12 | lima
# Processing Record 25 of Set 12 | visnes
# Processing Record 26 of Set 12 | amberley
# Processing Record 27 of Set 12 | quepos
# Processing Record 28 of Set 12 | yenagoa
# Processing Record 29 of Set 12 | ixtapa
# Processing Record 30 of Set 12 | prince albert
# Processing Record 31 of Set 12 | mocuba
# Processing Record 32 of Set 12 | kiruna
# Processing Record 33 of Set 12 | sembe
# Processing Record 34 of Set 12 | vostok
# Processing Record 35 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 12 | caraballeda
# Processing Record 37 of Set 12 | verkhoyansk
# Processing Record 38 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | shu
# Processing Record 40 of Set 12 | aklavik
# Processing Record 41 of Set 12 | waddan
# Processing Record 42 of Set 12 | damaturu
# Processing Record 43 of Set 12 | ambam
# Processing Record 44 of Set 12 | strumica
# Processing Record 45 of Set 12 | zhelyabovka
# Processing Record 46 of Set 12 | beirut
# Processing Record 47 of Set 12 | ashqelon
# Processing Record 48 of Set 12 | niamey
# Processing Record 49 of Set 12 | acurenam
# Processing Record 0 of Set 13 | taywarah
# Processing Record 1 of Set 13 | timra
# Processing Record 2 of Set 13 | portland
# Processing Record 3 of Set 13 | debre sina
# Processing Record 4 of Set 13 | sechura
# Processing Record 5 of Set 13 | eureka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          546
# Lat           546
# Lng           546
# Max Temp      546
# Humidity      546
# Cloudiness    546
# Wind Speed    546
# Country       546
# Date          546
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     atuona  -9.8000 -139.0333     25.48        75          55        7.57
# 1     hobart -42.8794  147.3294     11.81        73          75        0.00
# 2       ikom   5.9667    8.7063     25.82        55          80        1.41
# 3  saskylakh  71.9167  114.0833    -34.54       100         100        3.13
# 4     aqtobe  50.2797   57.2072    -11.95        72           0        1.00
#
#   Country        Date
# 0      PF  1669838235
# 1      AU  1669838440
# 2      NG  1669838226
# 3      RU  1669838296
# 4      KZ  1669838226

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           atuona  -9.8000 -139.0333     25.48        75          55
# 1           hobart -42.8794  147.3294     11.81        73          75
# 2             ikom   5.9667    8.7063     25.82        55          80
# 3        saskylakh  71.9167  114.0833    -34.54       100         100
# 4           aqtobe  50.2797   57.2072    -11.95        72           0
#
#          Wind Speed Country        Date
# City_ID
# 0              7.57      PF  1669838235
# 1              0.00      AU  1669838440
# 2              1.41      NG  1669838226
# 3              3.13      RU  1669838296
# 4              1.00      KZ  1669838226

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], facecolor = "steelblue", edgecolor = "black")


# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_regress(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    print(f"The r-value is: {rvalue**2}")
    return line_eq
#Define function to annotate regression plot
def annotate(line_eq, x, y):
    plt.annotate(line_eq,(x,y),fontsize=15,color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             ikom   5.9667    8.7063     25.82        55          80
# 3        saskylakh  71.9167  114.0833    -34.54       100         100
# 4           aqtobe  50.2797   57.2072    -11.95        72           0
# 5         tasiilaq  65.6145  -37.6368      1.68        96         100
# 7           albany  42.6001  -73.9662     11.64        91         100
#
#          Wind Speed Country        Date
# City_ID
# 2              1.41      NG  1669838226
# 3              3.13      RU  1669838296
# 4              1.00      KZ  1669838226
# 5              9.68      GL  1669838316
# 7              2.68      US  1669838286

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         atuona  -9.8000 -139.0333     25.48        75          55
# 1         hobart -42.8794  147.3294     11.81        73          75
# 6           chuy -33.6971  -53.4616     24.18        72          15
# 10       ushuaia -54.8000  -68.3000     11.81        50          75
# 13         maraa  -1.8333  -65.3667     30.25        66         100
#
#          Wind Speed Country        Date
# City_ID
# 0              7.57      PF  1669838235
# 1              0.00      AU  1669838440
# 6              7.62      UY  1669838441
# 10            12.35      AR  1669838229
# 13             0.45      BR  1669838230

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot = lin_regress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")

#Annotate regression
annotate(plot, 0,-20)
# Out:
# The r-value is: 0.7031047657713505

# %%
# Linear regression on Southern Hemisphere
plot = lin_regress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")

#Annotate regression
annotate(plot, -30,10)
# Out:
# The r-value is: 0.3434879138801734

# %% [markdown]
# **Discussion about the linear relationship:**
# In the Northern Hemisphere there is a pretty strong correlation between latitude and max temps with an r-value of 0.703, this tells us that as the latitude gets higher our Max Temps drops.
#
# In the Southern hemisphere we have a weak correlation between Max Temps and Latitude with an r-value of 0.343, still we see that as latitude increases our Max Temps Rise.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot = lin_regress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")

#Annotate regression
annotate(plot, 45,20)
# Out:
# The r-value is: 0.09965475933057102

# %%
# Southern Hemisphere
plot = lin_regress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("humidity")

#Annotate regression
annotate(plot, -50,20)
# Out:
# The r-value is: 0.10076229220561357

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere there is not a significant correlation between latitude and humidity with an r-value of 0.100, we can see in the graph that the correlation is there but the results seem to vary with no signifact relationship to each other
#
# In the Southern hemisphere we have essentially the same correlation with an r-value of 0.101, the graphs dont change much in appearnce once again the correlation can be seen but is weak and many points on the plot dont seem to follow it.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot = lin_regress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

#Annotate regression
annotate(plot, 45,25)
# Out:
# The r-value is: 0.03827489922135806

# %%
# Southern Hemisphere
plot = lin_regress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

#Annotate regression
annotate(plot, -50,20)
# Out:
# The r-value is: 0.09146174017459055

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere there is no correlation between latitude and Cloudiness with an r-value of 0.038.
#
# In the Southern hemisphere there is no significant correlation between latitude and Cloudiness with an r-value of 0.091.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot = lin_regress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

#Annotate regression
annotate(plot, 20,20)
# Out:
# The r-value is: 0.017514434822392896

# %%
# Southern Hemisphere
plot = lin_regress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

#Annotate regression
annotate(plot, -50,14)
# Out:
# The r-value is: 0.13750863643757263

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere there is not a significant correlation between latitude and Wind Speed with an r-value of 0.018, despite that from seeing the graph it seems like in general wind speeds are lower.
#
# In the Southern hemisphere there is a slightly higher correlation but still not significant with an r-value of 0.138.
